# %%
import csv
import os
import string
import random
import collections
from collections import defaultdict
import shutil
from datetime import date, datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
fileDir = os.path.dirname(os.path.realpath('__file__'))
currentdate = date.today().strftime('%Y.%m.%d')
# currentdate = '2019.04.02'
import json
SYMBOLS = [' ', '/', '-', '&', ',', '\’','\‘', '\'', "'"]


def move_files(filename):
    shutil.move("%s/%s" %(fileDir, filename), "%s/RESULTS/%s" %(fileDir, filename))

def create_file(filename, df):
    df.to_excel(filename, index=False)
    move_files(filename)

def clean_column(df, column):
    for symbol in SYMBOLS:
        df["%s" %column] = df["%s" %column].astype(str).str.replace(r'%s' % symbol,'')
    return df

''' STANDAARD '''
# Out:
# ' STANDAARD '

# %%
def clean_rows_pageviews(row):
    data = row['dimensions']
    row['clientid'] = data[0]
    row['sessionid'] = data[1]
#     row['date'] = data[2].split('T')[0]
    row['time']= data[2]
    row['keyword'] = data[3]
    row['category'] = data[4]
    return row

# Deze functie gebruiken bij hele data set, hieronder wordt functie gebruikt waar maar 1000 instances worden geladen
def create_dataframe_pageviews(filename):
    with open(f"Searchdata/{filename}", "r") as read_file:
        data = json.load(read_file)
    new_data = data['reports'][0]['data']['rows']
    df = pd.DataFrame.from_dict(new_data)
    df = df.apply(clean_rows_pageviews, axis=1)
    df.drop(columns=['dimensions', 'metrics'], inplace=True)

    # print(df.head())
    # print(df.shape)
    # print(df.info())
    return df

# %%
df = create_dataframe_pageviews('searches-2020-07-30.json')

# %%
searches_list = []
path = 'Searchdata/'

for file in os.listdir(path):
    print(f'Reading files for: {file}\n')

    df_pageview = create_dataframe_pageviews(file)
    print(df_pageview.shape)
    mylist = list(df.keyword.unique())
    searches_list.append(mylist)
# Out:
# Reading files for: searches-2020-12-20.json
#
# (198, 5)
# Reading files for: searches-2020-09-21.json
#
# (1873, 5)
# Reading files for: searches-2020-11-25.json
#
# (1621, 5)
# Reading files for: searches-2020-08-14.json
#
# (3058, 5)
# Reading files for: searches-2020-07-30.json
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     999         try:
# -> 1000             self._set_with_engine(key, value)
#    1001         except (KeyError, ValueError):
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1032         # fails with AttributeError for IntervalIndex
# -> 1033         loc = self.index._engine.get_loc(key)
#    1034         validate_numeric_casting(self.dtype, value)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sessionid'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-073b3cecbab6> in <module>
#       5     print(f'Reading files for: {file}\n')
#       6
# ----> 7     df_pageview = create_dataframe_pageviews(file)
#       8     print(df_pageview.shape)
#       9     mylist = list(df.keyword.unique())
#
# <ipython-input-22-23fbf110890c> in create_dataframe_pageviews(filename)
#      15     new_data = data['reports'][0]['data']['rows']
#      16     df = pd.DataFrame.from_dict(new_data)
# ---> 17     df = df.apply(clean_rows_pageviews, axis=1)
#      18     df.drop(columns=['dimensions', 'metrics'], inplace=True)
#      19
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     269
#     270     def apply_standard(self):
# --> 271         results, res_index = self.apply_series_generator()
#     272
#     273         # wrap results
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     298                 for i, v in enumerate(series_gen):
#     299                     # ignore SettingWithCopy here in case the user mutates
# --> 300                     results[i] = self.f(v)
#     301                     if isinstance(results[i], ABCSeries):
#     302                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-22-23fbf110890c> in clean_rows_pageviews(row)
#       2     data = row['dimensions']
#       3     row['clientid'] = data[0]
# ----> 4     row['sessionid'] = data[1]
#       5 #     row['date'] = data[2].split('T')[0]
#       6     row['time']= data[2]
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1006             else:
#    1007                 # GH#12862 adding an new key to the Series
# -> 1008                 self.loc[key] = value
#    1009
#    1010         except TypeError as err:
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1624
#    1625             if missing:
# -> 1626                 self._setitem_with_indexer_missing(indexer, value)
#    1627                 return
#    1628
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    1827
#    1828             # this preserves dtype of the value
# -> 1829             new_values = Series([value])._values
#    1830             if len(self.obj._values):
#    1831                 # GH#22717 handle casting compatibility that np.concatenate
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     325                     data = data.copy()
#     326             else:
# --> 327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
#     329                 data = SingleBlockManager.from_array(data, index)
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     449             subarr = maybe_convert_platform(data)
#     450
# --> 451         subarr = maybe_cast_to_datetime(subarr, dtype)
#     452
#     453     elif isinstance(data, range):
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1439             )
#    1440         ):
# -> 1441             value = maybe_infer_to_datetimelike(value)
#    1442
#    1443     return value
#
# /home/hulu/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#    1279             return np.asarray(td_values).reshape(shape)
#    1280
# -> 1281     inferred_type = lib.infer_datetimelike_array(ensure_object(v))
#    1282
#    1283     if inferred_type == "date" and convert_dates:
#
# KeyboardInterrupt:

# %%
mylist = list(df.keyword.unique())

print(len(mylist))
mylist
# Out:
# 1308
# ['Den Haag',
#  'Apeldoorn',
#  'Brabant',
#  'utrecht',
#  'utrecht\\',
#  'Rotterdam',
#  'Utrecht',
#  'Leiden',
#  'Amsterdam',
#  'Amersfoort',
#  'adreswijziging doorgeven',
#  'Enkhuizen',
#  'Dordrecht',
#  'Den Bosch',
#  '‘S Hertogenbosch',
#  'Terschelling',
#  'open',
#  'Openluchtmuseum',
#  'Corpus',
#  'Nijmegen',
#  'muzeeum',
#  'franeker',
#  'friesland',
#  'groningen',
#  'Kroller',
#  'Openlucht',
#  'Otterlo',
#  'doneren',
#  'Zeeland',
#  'Gelderland',
#  'Gelderland natuur en dieren',
#  'natuur en dieren musea in Gelderland',
#  'ootmarsum',
#  'stedelijk museum alkmaar',
#  'Mienen',
#  'Nuenen',
#  'Groningen',
#  'Bourtange',
#  'Eisinga',
#  'Stavoren',
#  'Arnhem',
#  'military',
#  'Space',
#  'Registreren',
#  'Escher',
#  'Esscher',
#  'neeltje jans',
#  'rijk',
#  'het keringhuis',
#  'van gogh',
#  'van gogh museum',
#  'Eye',
#  'den haag',
#  'arnhem',
#  'deventer',
#  'Alkmaar',
#  'Assen',
#  'amsterdam',
#  'rijksmuseum',
#  'gogh',
#  'tilburg',
#  'Katwijk',
#  'leeuwarden',
#  'leiden',
#  'Den haag',
#  'Voorlinden',
#  'wadenaar',
#  'Wassenaar',
#  'Louwman',
#  'Nmm',
#  'Archeologen',
#  'Archeon',
#  'den bosch',
#  'verlengen',
#  'Eindhoven',
#  'Achterhoek',
#  'Zuid limburg',
#  'Valkenburg',
#  'Veendam',
#  'Veenhuis',
#  'Goes',
#  'Muiderslot',
#  'nijmegen',
#  'berg en dal',
#  'Madam',
#  'Madam tusshau',
#  'madame tussauds',
#  'Kasteel',
#  'Kasteel Gelderland',
#  'Museumkaart verlengen',
#  'limburg',
#  'Museum in Zwartsluis',
#  'kasteel in Heino/Wijhe',
#  'Kasteel museum in Heino',
#  'Museum Stevensweert',
#  'Noord Brabant',
#  'Beverwijk',
#  'Ijmuiden',
#  'Wijk aan zee',
#  'Haarlem',
#  'Zandvoort',
#  'Bloemendaal',
#  'As',
#  'Asscher',
#  'Naturalis',
#  'Nemo',
#  'Voorlieden',
#  'Anne Frank',
#  'Voor',
#  'Voorzijde',
#  'Moco',
#  'Nico',
#  'valkenswaard',
#  'kasteel de haar',
#  'B',
#  'Batavia',
#  'Kastelen',
#  'roermond',
#  'apeldoorn',
#  'hortus',
#  'ecomare',
#  'texel',
#  'eindhoven',
#  'tech',
#  'Kinderdijk',
#  'Zuid Holland',
#  'Corona',
#  'Prijs',
#  'Militair',
#  'Muiden',
#  'almere',
#  'hilversum',
#  'museon',
#  'oudheden',
#  'foam',
#  'moco',
#  'waalwijk',
#  'Burgers zo',
#  'Ameland',
#  'Mocro',
#  'Winkel',
#  'Grootmoeders',
#  'Leeuwarden',
#  'Jaarbeurs',
#  'Jaarbeurs Utrecht',
#  'Fort pampus',
#  'Oss',
#  'Nijverdal',
#  'enschede',
#  'twente',
#  'kaart beeindigen',
#  'kaart stopzetten',
#  'kosten',
#  'soest',
#  'lelystad',
#  'enkhuizen',
#  'avidrome',
#  'Avifauna,',
#  'aviodrome',
#  'Maastricht',
#  'Nieuw',
#  'geofort',
#  'registreren',
#  'veenhuizen',
#  'Marine museum',
#  'Den Helder',
#  'Tiel',
#  'Bergen op zoom',
#  'Hoorn',
#  'Medemblik',
#  'Mauritshuis',
#  'Garderen',
#  'hindelopen',
#  'rotterdam',
#  'Openlucht museum arnhem',
#  'Botanische tuin Utrecht',
#  'Verhuizing',
#  'Zaandam',
#  'Helmantel',
#  'Hel',
#  'De weem',
#  'Maarten van Rossum',
#  'Zaltbommel',
#  'Rijksmuseum',
#  'game',
#  'oudhe',
#  'video',
#  'zoetermeer',
#  'Leiden met museumkaart',
#  'Hazerswoude',
#  'noord holland',
#  'landgoed coendersborg',
#  'Nuis',
#  'Leek',
#  'Friesland',
#  'Veenhuizen',
#  'Bakkeveen',
#  'zevenhuizen',
#  'Westerkwartier',
#  'Tilburg',
#  'Zwolle',
#  'Hattem',
#  'Epe',
#  'Oene',
#  'Kruller',
#  'Drenthe',
#  'gulpen',
#  'Vaals',
#  'woerden',
#  'gouda',
#  'vleuten',
#  'zuid holland',
#  'Vragen',
#  'oertijd museum',
#  'prehistorisch dorp',
#  'Delfzijl',
#  'Burgers',
#  'Burgerszoo',
#  'Soest',
#  'lauwman',
#  'louwman',
#  'oorlog',
#  'spoorweg',
#  'oorlogsmuseum',
#  'mariniers',
#  'scheepvaart',
#  'scheepvaartrotterdam',
#  'naturalis',
#  'schunck',
#  'gelderland',
#  'American Pilgrim Museum',
#  'dokkum',
#  'Spoorweg',
#  'Hilversu',
#  'Hilversum',
#  'Gooi',
#  'Museumjaarkaart kind',
#  'Opzeggen',
#  'more',
#  '.gelderland',
#  'rijks',
#  'rijks museum',
#  'stedelijk',
#  'Vught',
#  'Leersum',
#  'natuurmuseum',
#  'Natuurmuseum',
#  'Natuurmuseum nijmegen',
#  'flevoland',
#  'veenpark',
#  'Amstrtdam',
#  'Is de museumjaarkaart 2019 nog geldig',
#  'zeeland',
#  'hortus amsterdam',
#  'Noord',
#  'Emmen',
#  'Wezup',
#  'Westerbork',
#  'Flevoland',
#  'Overijssel',
#  'maastricht',
#  'Oirsbeek',
#  'Valkenburg Limburg',
#  'Den bosch',
#  'dierentuin',
#  'Den helder',
#  'Oorlog den helder',
#  'Oorlog denkbeelden',
#  'Gevangenis',
#  'Openluchtmuseum arnhem',
#  'Openluchtmuseum arnhem reserveren',
#  'Wonder',
#  'Wonderexperience',
#  'Xperience',
#  'Onderste',
#  'Wondr',
#  'Bevrijdende vleugels',
#  'Avg',
#  'Foto',
#  'SVG',
#  'dating',
#  'Wijzigen gegevens',
#  'Zuid holland',
#  'Schiedam',
#  'Vlaardingen',
#  'Maassluis',
#  'phot',
#  'photo',
#  'world press',
#  'world',
#  'Cuypershuis',
#  'verlenging door corona',
#  'dukkum',
#  'sneek',
#  'Noord brabant',
#  'Limburg',
#  'Twente',
#  'Zutphen',
#  'delft',
#  'openlucht museum arnhem',
#  'Openluchtmuseum.nl',
#  'rietveld',
#  'Lego',
#  'Panorama mesdag',
#  'Escher Den haag',
#  'Denbhaag',
#  'Escher Innhet paleis',
#  'singermuseum laren',
#  'Oranjewoud',
#  'Korting',
#  'Introdicee',
#  'Rijksmuseum amsterdam',
#  'Amsterdam rijksmuseum',
#  'Hindel',
#  'Schaats',
#  'Schaatsmuseum',
#  'Tuinencomplex',
#  'Aviodrome',
#  'Lelystad',
#  'mode',
#  'Rijk',
#  'Breda',
#  'Van Gogh museum',
#  'Groesbeek',
#  'Geofort',
#  'Ens',
#  'Schokland',
#  'PrijZen',
#  'Fort 1881',
#  'Hoek van holla d',
#  'Hoek van hollana',
#  'Hoek van holland',
#  'Bastei',
#  'vught',
#  'Rijksmuseum Amsterdam',
#  'Rijksmuseum Amsterdam kaarten',
#  'Gebruik link museumjaarkaart',
#  'Annefrankhuis',
#  'Kasteel Duivenvoorde',
#  'Anne frankhuis',
#  'Museumkaart verloren',
#  'textiel',
#  'kasteel',
#  'Kroller muller',
#  'gravenhage',
#  'haag',
#  'corona',
#  'van Gogh',
#  'Markelo',
#  'Staphorst',
#  'Nieuwleusen',
#  'neeltje',
#  'molemwaard',
#  'molenwaard',
#  'Watermuseum',
#  'hernen',
#  'Den bisch',
#  'corpus',
#  'Klok en peel',
#  'Zuiderzee',
#  'Beeld en geluid',
#  'Hermitage',
#  'Nijntje',
#  'Aandelen',
#  'Nederlandse bank',
#  'Stock',
#  'Baarn',
#  'Laren',
#  'Westkapelle',
#  'Duplicaat pas',
#  'Opeb',
#  'kunstmuseum den haag',
#  'sittard',
#  'mauritshuis',
#  'neede',
#  'Neeltje jans',
#  'univerd',
#  'universiteitsm',
#  'universiteitsmuseum',
#  'universiteitsmuseum utrecht',
#  'More',
#  'Noordwijkerhout',
#  'Gron8ngen',
#  'Borger',
#  "'s-Hertogenbosch",
#  'Nederland',
#  'Aopel',
#  'dordrecht',
#  'Heino',
#  'gestolen',
#  'Brielle',
#  'Bosch',
#  'hermitage',
#  'Kampen',
#  'Strip museum',
#  'Strip museum Groningen',
#  'Beerze',
#  'Ommen',
#  'Orvelte',
#  'Museum dorp orvelte',
#  'zout',
#  'openlucht',
#  'openluchtmuseum arnhem',
#  'beeld',
#  'Middelburg',
#  'naturaralis',
#  'Haarzuilens',
#  'hengelo',
#  'Wondr experience',
#  'Bakkerijmuseum',
#  'Hattum',
#  'tolen',
#  'Schijndel',
#  'Delft',
#  'Volendam',
#  'Sint pieter',
#  'Ter apel',
#  '2e wereldoorlog',
#  'Overijasel',
#  'Arcen',
#  'assen',
#  'Madurodam',
#  'de pont',
#  'moderne kunst',
#  'pont',
#  'vergeten te betalen',
#  'Gorinchem',
#  'museumkaart kopen in museum',
#  'Artillerie mus um',
#  'design museum',
#  'Kröller',
#  'appelscha',
#  'musea in appelscha',
#  'musea in Fochteloo',
#  'museum in zogvlied',
#  'museum in zorgvlied',
#  'fundatie',
#  'Geldigheid',
#  'alkmaar',
#  'zutphen',
#  'den bisch',
#  'brabant',
#  'Giethoorn',
#  'Stedelijk',
#  'Stedelijk museum amsterdam',
#  'Groninger',
#  'Groninger museum',
#  'Textiel museum',
#  'Textiel museum Tilburg',
#  'Textiel tilburg',
#  'verhildersum',
#  'madurodam',
#  'foto',
#  'Loenen',
#  'Afsluitdijk',
#  'Bergen',
#  'Neede',
#  'Borculo',
#  'Haaksbergen',
#  'Lochem',
#  'Enschede',
#  'Hengelo',
#  'Oldenzaal',
#  'Ruurlo',
#  'Winterswijk',
#  'Groenlo',
#  'Lichtenvoorde',
#  'Delden',
#  'Overlijden',
#  'drenthe',
#  'Vlissingen',
#  'Gouda',
#  'Can',
#  'van',
#  'Portugees synagogue',
#  'overijssel',
#  'achterhoek',
#  'onderduik',
#  'valkhof',
#  'orgel',
#  'willem sluiter',
#  'bataviawerf',
#  'Doornenburg',
#  'Kasteel de haar',
#  'Marie museum',
#  'Marine',
#  'vacature',
#  'museumkaart',
#  'zeeuws',
#  'rijksmuseum oudheden',
#  'borger',
#  'drouwen',
#  'emmen',
#  'voorlinden',
#  'Vrijmetse',
#  'Vrijmetselaar',
#  'Vrijmetsel',
#  'middelburg',
#  'middelburg zeeland',
#  'Harderwijk',
#  'Nunspeet',
#  'Elburg',
#  'spoorwegmuseum',
#  'briel',
#  'stenen baak',
#  'Contact',
#  'Covid',
#  'Van Gogh',
#  'leerdam',
#  'valkenburg',
#  'Valkenburg aan de geul',
#  'steen',
#  'westlands',
#  'westl',
#  'Huizen',
#  'Beverwijks museum',
#  'Museum Kennemerland',
#  'de fundatie',
#  'zwolle',
#  'oegstgeest',
#  'Transport',
#  'Overijsel',
#  'Eiland',
#  'Maritiem museum',
#  'Maritiem museum den helder',
#  'Landgoed',
#  'Naarden',
#  'Grote Kerk Naarden',
#  'Airborne',
#  'hoorn',
#  'Vriezenveen',
#  'Almelo',
#  'Hoogeveen',
#  'Hoenderloo',
#  'Kamp vught',
#  'Watersnoodramp museum',
#  'Bevrijdingsmuseum',
#  'Watersnoodmuseum',
#  'Paleis het loo',
#  'Scheveningen',
#  'Ermelo',
#  'Veluwe',
#  'Arnhem openluchtmuseum',
#  'Foam',
#  'Sneek',
#  'weesp',
#  'Meppel',
#  'gevangenis museum',
#  'volendam',
#  'LAM',
#  'LAM lisse',
#  'Het Loo',
#  'pluimvee',
#  'pluimveemuseum',
#  'belvedere',
#  'mow',
#  'rembrandthuis',
#  'prinsenhof',
#  'helmond',
#  'museum helmond',
#  'caravaggio',
#  'Caravaggio-Bernini',
#  'JAN',
#  'beelden aan zee',
#  'kunsthal',
#  'tweestromenland',
#  'slager',
#  'Boerhaave',
#  'diepenheim',
#  'kunstmuseum',
#  'Kröller-Müller',
#  'mode op de bon',
#  'Kati Heck',
#  'schiedam',
#  'stedelijk museum schiedam',
#  'verzet',
#  'verzetsmuseum',
#  'philips',
#  'philips museum',
#  'jenever',
#  'jenevermuseum',
#  'bolwerk',
#  'gorcums',
#  'instituut',
#  'westlands museum',
#  'westfries',
#  'Zandsculpturen',
#  'oranjehotel',
#  'tijdelijke museumkaart',
#  'Mijn museumkaart',
#  'Veel gestelde vragen',
#  'Maurits',
#  'Lisse',
#  'Spoor',
#  'van ghog',
#  'van go',
#  'van gohg',
#  'openlucht museum',
#  'De haar',
#  'Kasteel De haar',
#  'Vergeten',
#  'Leiderdorp',
#  'body museum',
#  'body museum amsterdam',
#  'body worlds amsterdam',
#  'body worlds',
#  'tropenmuseum',
#  'Rundvee useum',
#  'Rundvee museum artswoud',
#  'haarlem',
#  'Leerdam',
#  'groen',
#  'Overloon',
#  'Sevenum',
#  'Speeltuin overloon',
#  'De Haar',
#  'Museum der oudheden',
#  'opzeggen',
#  'opzeggen museumkaart',
#  'beeindigen museumkaart',
#  'Activeren',
#  'Pinbal',
#  'openluchtmuseum',
#  'Micropia',
#  'contact',
#  'kaart kwijt',
#  'Fiam',
#  'arbor',
#  'trompen',
#  'trompenb',
#  'Nieuw Vennep',
#  'Nieuw-vennep',
#  'ams',
#  'Mensinge roden',
#  'boxtel',
#  'Oertijdmuseun',
#  'inloggen',
#  'Appeldoorn',
#  'breda',
#  'Aangesloten musea',
#  'museum kasteel wijchen',
#  'biesboch',
#  'museumeiland',
#  'Van',
#  'Grachtenhuis',
#  'Grachtenmuseum Amsterdam',
#  'ermelo',
#  'venlo',
#  'botanische tuinen',
#  'Nieuwe kerk',
#  'DAF Museum',
#  'lelystaD',
#  'kampen',
#  'registeren',
#  'sliedrecht',
#  'sliedrechts museum',
#  'gorinchem',
#  'rhenen',
#  'putten',
#  'Texel',
#  'Kwijt',
#  'nijntje',
#  'boekenmuseum',
#  'kinderboekenmuseum',
#  'jan kruis',
#  'coevorden',
#  'registreer',
#  'Regiment',
#  'Kamp amersfoort',
#  'Kopen',
#  'niet vinden',
#  'verloren',
#  'vinden',
#  'space',
#  'musea',
#  'Gogh',
#  'avio',
#  'Aftrek',
#  'Volken museum',
#  'louwman museum',
#  'louwmanmuseum',
#  'diergaarde blijdorp',
#  'Oudenbosch',
#  'Paleis het Loo',
#  'Beesd',
#  'Deil',
#  'Vianen',
#  'Loevestein',
#  'Miniatuur',
#  'doesburg',
#  'Doesburg',
#  'Boxtel',
#  'Haaren',
#  'Liempde',
#  'Lu',
#  'Oisterwijk',
#  'Best',
#  'Beëindiging',
#  'veel gestelde vragen',
#  'Hoogersmilde',
#  'verborgen parel',
#  'Heemstede',
#  'Holten',
#  'Durgerdam',
#  'Marken',
#  'Jutter',
#  'kroller',
#  'amersfoort',
#  'Tot zover',
#  'Hoe duur',
#  'Wat kost het',
#  'hulst',
#  'Tropenmuseum',
#  'artis',
#  'micropia',
#  'zoo',
#  'Natu',
#  'air',
#  'Aviodome',
#  'Aviodro',
#  'Lely',
#  'vliegtuigen',
#  'av',
#  'Avi',
#  'Avio',
#  'Av',
#  'leleystsd',
#  'Vliegtuigen',
#  'fr.scheepv.m',
#  'tiel',
#  'PROVINCIE FRIESLAND',
#  'amstelveen',
#  'musea zuid holland',
#  'prijs meuseum jaarkaart',
#  'prijs museum jaarkaart',
#  'wat kost een museum jaarkaart',
#  'wat kost een museumkaart',
#  'Yerseke',
#  'Heerlen',
#  'Scheepvaartmuseum',
#  'bakkeveen',
#  'haulerwijk',
#  'wondr',
#  'wond',
#  'terug gave',
#  'teruggave',
#  'Sittard',
#  'provincie Gelderland o tot 12 jaar voor kinderen',
#  'Leuk voor kinderen',
#  'Neeltje',
#  'kamp vught',
#  'Ede',
#  'noord',
#  'Voorburg',
#  'Rijswijk',
#  'expedition earth',
#  'Afmelden',
#  'Arsenaal',
#  'oosterhout',
#  'Roermond',
#  'Thorn',
#  'verlinde museum',
#  'Rockanje',
#  'Zuidholland',
#  'Zuid-holland',
#  'Honselersdijk',
#  'Redding',
#  'Reddings',
#  'Reddingsmuseum',
#  'Helder',
#  'Welke musea',
#  'Archein',
#  'Maduridam',
#  'Tijdelijk',
#  'de haar',
#  'geldigheid i.v.m. corona',
#  'doetinchem',
#  'Reddingmuseum',
#  'beeld en geluid',
#  'reddingmuseum',
#  'archeon',
#  'kuiperij',
#  'jisperhuisje',
#  'kamp westerbork',
#  'openli=uchtmuseum arnhem',
#  'loo',
#  'airborne museum',
#  'batavialand',
#  'agrarisch museum',
#  'Uden',
#  'Veghel',
#  'World press',
#  'schagen',
#  'bergen',
#  'Militair museum',
#  'nemo',
#  'Catherijne',
#  'Corp',
#  'CorpUs',
#  'Oegstgeest',
#  'Van Gogh park',
#  'Duivenvoorde',
#  'gevangenis',
#  'gevangenismuseum',
#  'Stedelijk museum',
#  'eise',
#  'drachten',
#  'Dokkum',
#  'Gorredijk',
#  'Heerenveen',
#  'Fries museum',
#  'Hubertus',
#  'lakenhal',
#  'En',
#  'Tu delft',
#  'eise eisinga',
#  'tijdelijke kaart',
#  'kaart cadeau doen',
#  'ktoller',
#  'Wijzigen e mail adres',
#  'Noordwijk',
#  'Halfweg',
#  'Grotten',
#  'Mergelrijk',
#  'Museum voorlinden',
#  'Juttersmuseum',
#  'CORPUS',
#  'madame',
#  'tussea',
#  'activeren',
#  'Deventer',
#  'Twello',
#  'Noord Limburg',
#  'Noord-limburg',
#  'GroningenStad',
#  'bakkerij museum',
#  'geldermalsen',
#  'ALKMAAR',
#  'LKMAAR',
#  'Franeker',
#  'Verloren',
#  'Pampus',
#  'Voorschoten',
#  'Eindhov3n',
#  'Eindhovenkamp vught ov',
#  'Hollum',
#  'Maritime',
#  'Maritime Museum',
#  'Euromast',
#  'Prij',
#  'Dolfinarium',
#  'bloemendaal',
#  'bloemendaal aan zee',
#  'krullemuller',
#  'Noord Holland',
#  'Edam',
#  'gemeentegrot',
#  'Egmond',
#  'orientalis',
#  'museum in Delft',
#  'Middelbirg',
#  'Kasteel Nijenhuis Heino/Wijhe',
#  'Museum Heino',
#  'Museum Heino/Wijhe',
#  'Museum in Heino',
#  'Museum Heino overijssel',
#  'Klooster',
#  'Openlucht museum',
#  'dinoland',
#  'Boottocht',
#  'Enkhuizen Stavoren',
#  'Tuinen',
#  'Maarssen',
#  'pretparken',
#  'Doetinchem',
#  'stadskasteel zaltbommel',
#  'psv',
#  'Cadzand',
#  'Zeeuws vlaanderen',
#  'museum deventer',
#  'museum geert het grote huis',
#  'geert het grote huis',
#  'Nationaal militair',
#  'ti',
#  'Zuid Limburg',
#  'kaart gegevens wijzigen',
#  'Bunnik',
#  'Militair museum Soest',
#  'Soest Militair museum',
#  'Hermitage amsterdam',
#  'museumkaart verloren',
#  'barneveld',
#  'Bakker',
#  'Kunsthal',
#  'Feyenoord de kuip',
#  'Heesch',
#  'Berghem',
#  'museum arnhem',
#  'Herinneringskamp Westerbork',
#  'harderwijk',
#  'hardewijk',
#  'nieuwdorp',
#  'Boerhave',
#  'opzeggen pdf',
#  'museumkaart opzeggen',
#  'kristal',
#  'donatie',
#  'Musea noord holland',
#  'Adreswijziging',
#  'Klantenservice',
#  'Keukenhof',
#  'Youmuseum',
#  'america',
#  'musea rondom america',
#  'horst',
#  'Provincie limburg',
#  'Museum in provincie limburg',
#  'drents museum',
#  'MORE Gorssel',
#  'Joods historisch museum',
#  'Delta',
#  'Zoetermeer',
#  'Etten-Leur',
#  'e-mailadres',
#  'africa',
#  'afrika museum',
#  'Heeze',
#  'Wonder amsterdam',
#  'Bies',
#  'Biesbosch',
#  'Fhiserhuske',
#  'Fiserhuske',
#  'Peasens',
#  'heeswijk',
#  'kastelen',
#  'koln',
#  'S-hertogenbosch',
#  'Velp',
#  'Natuurhistorische',
#  'Natuurhistorische museum',
#  'Spoorweg museum',
#  'Kun',
#  'Amstelveen',
#  'Provincies',
#  'student',
#  'tandheelkunde museum',
#  'tandheelkunde museum Utrecht',
#  'Utrecht tandheelkundig museum',
#  'muzeumkaart prijs',
#  'muzeumkaartkosten',
#  'prijs',
#  'prijs muzeumkaart',
#  'muzeumkaart kosten',
#  'Stoomtrein goes',
#  'amelisweerd',
#  'utreht',
#  'Kaart kwijt',
#  'Vervangende kaart',
#  'Verlies kaart',
#  'Kind',
#  'Zierikzee',
#  'siroopwafel',
#  'stroopwafel',
#  'maritiem',
#  'Kasteel Nijenhuis',
#  'meest gestelde vragen',
#  'den helder',
#  'Alphen',
#  'boskoop',
#  'haarlemmeer',
#  'Schoonhoven',
#  'rijksmuzeum',
#  'RIJKSMUSEUM',
#  'Fundatie',
#  'pampus',
#  'Museum voorlinde',
#  'Voorlinde',
#  'Noord holland',
#  'Schepen',
#  'Varen',
#  'Geloof',
#  'Agrarisch',
#  'b',
#  'c',
#  'zaandam',
#  'purmerend',
#  'middenbeemster',
#  'de rijp',
#  'het houtenhuis',
#  'muiderslot',
#  'onze live heer op sloder',
#  'art museum',
#  'art museum den bosch',
#  'noord brbands museum',
#  'Keramiek',
#  'edelsteen',
#  'water',
#  'waternood',
#  'waternoodmuseum',
#  'Registreer',
#  ...]
